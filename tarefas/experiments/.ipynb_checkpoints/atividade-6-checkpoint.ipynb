# %%
import os

import cv2
import numpy as np
from skimage import measure

import pylab as plt
# %matplotlib inline

# %%
def exibir_imagens(list_process=None):
    if isinstance(list_process, list):
        for obj in list_process:
            plt.figure()
            plt.title(s=obj.get('title', ''))
            plt.xticks(obj.get('xticks', []))
            plt.yticks(obj.get('yticks', []))
            plt.imshow(X=obj.get('X'), cmap=obj.get('cmap', None))
            plt.tight_layout()
    else:
        obj = list_process
        plt.figure()
        plt.title(s=obj.get('title', ''))
        plt.xticks(obj.get('xticks', []))
        plt.yticks(obj.get('yticks', []))
        plt.imshow(X=obj.get('X'), cmap=obj.get('cmap', None))
        plt.tight_layout()

# %%
path = os.getcwd() + os.sep
png = path + '../../db_images/png/captcha.png'
jpeg = path + '../../db_images/jpeg/captcha.jpeg'
other = path + '../../db_aulas/Imagens/tetris_blocks.png'

path_images = [other]

# %%
images = []
for path_img in path_images: 
    img = cv2.imread(path_img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    it = {'title': 'Original',
          'X': img}
    images.append(it)

grays = []
for obj in images:
    gray = cv2.cvtColor(obj['X'], cv2.COLOR_BGR2GRAY)
    it = {'cmap': 'gray',
          'title': 'Original Gray',
          'X': gray}
    grays.append(it)

# %%
exibir_imagens(images)

# %%
exibir_imagens(grays)

# %%
contours = []
for i in range(len(images)):
    gray = grays[i].copy()
    img = images[i].copy()

    img_gray = gray.get('X').copy()
    origin = img.get('X').copy()

    #img_gray = cv2.medianBlur(img_gray, 5)
    #img_gray = cv2.GaussianBlur(img_gray, (5,5), 0.)

    img_gray[(img_gray[:,:] > 233)] = 0

    (_, cnts, hierarquia) = cv2.findContours(img_gray, 
                                             cv2.RETR_EXTERNAL,
                                             cv2.CHAIN_APPROX_SIMPLE)
    clone = img.get('X').copy()
    cv2.drawContours(clone, cnts, -1, (255,0,255), 3)

    img.update({'X': clone})
    contours.append(img)

    gray.update({'X': img_gray, 'cnts': cnts, 'origin': origin})
    contours.append(gray)

# %%
exibir_imagens(contours)

# %%
objetos = []
for img_contour in contours:
    if img_contour.get('cnts'):
        cnts = img_contour.get('cnts')
        for i, c in enumerate(cnts):
            img = img_contour.copy()
            
            clone = img.get('origin').copy()
            
            mask = np.zeros(img.get('X').shape, dtype='uint8')
            cv2.drawContours(mask, [c], -1, 255, -1)
            
            img.update(
                {
                    'title': str((i))+' Image + Mask',
                    'X': cv2.bitwise_and(clone, clone, mask=mask),
                    'index': i
                }
            )
            objetos.append(img)

# %%
exibir_imagens(objetos)

# %%
rects_objs = []
for obj in objetos:
    it = obj.copy()
    cnts = it.get('cnts')
    for i, c in enumerate(cnts):
        if it.get('index') == i:
            it = obj.copy()
            clone = it.get('X')

            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(clone, (x,y), (x+w,y+h), (255,0,255), 2)

            it.update({'X': clone})
            rects_objs.append(it)

# %%
exibir_imagens(rects_objs)

# %%
rects_objs = []
for obj in objetos:
    it = obj.copy()
    label_img = measure.label(it.get('X'))
    props = measure.regionprops(label_img)
    
    print('id: {}'.format(it.get('index')))
    print('H:{}'.format(measure.shannon_entropy(it.get('X'), np.e)))
    print('area: {}'.format(props[0].area))
    print('bbox: {}'.format(props[0].bbox))
    print('bbox_area: {}'.format(props[0].bbox_area))
    print('centroid: {}'.format(props[0].centroid))
#     print(props[0].convex_area) # not 3d
#     print(props[0].convex_image) # not 3d

#   print(props[0].coords)

#     print(props[0].eccentricity)  # not 3d

    print('equivalent_diameter: {}'.format(props[0].equivalent_diameter))

#    print(props[0].euler_number)  # not 3d

    print('extent: {}'.format(props[0].extent))

#   print(props[0].filled_area)
#   print(props[0].filled_image)
#   print(props[0].image)
    
#     print(props[0].inertia_tensor) # not 3d
#     print(props[0].inertia_tensor_eigvals) # not 3d
#     print(props[0].intensity_image) # search docs
#     print(props[0].local_centroid) # not 3d
#     print(props[0].major_axis_length) # not 3d
#     print(props[0].max_intensity)
#     print(props[0].mean_intensity)
#     print(props[0].min_intensity)
#     print(props[0].minor_axis_length) # not 3d
#     print(props[0].moments)  # not 3d
#     print(props[0].moments_central)  # not 3d
#     print(props[0].moments_hu)  # not 3d
#     print(props[0].moments_normalized)  # not 3d
#     print(props[0].orientation) # not 3d
#     print(props[0].perimeter) # not 3d
#     print(props[0].solidity) # not 3d
#     print(props[0].weighted_centroid) # not 3d
#     print(props[0].weighted_local_centroid) # not 3d
#     print(props[0].weighted_moments) # not 3d
#     print(props[0].weighted_moments_central) # not 3d
#     print(props[0].weighted_moments_hu) # not 3d
#     print(props[0].weighted_moments_normalized) # not 3d

#     print('Moments R:\n{}'.format(measure.moments(it.get('X')[::,::,0]))) # not 3d
#     print('Moments G:\n{}'.format(measure.moments(it.get('X')[::,::,1]))) # not 3d
#     print('Moments B:\n{}'.format(measure.moments(it.get('X')[::,::,2]))) # not 3d

    print()
    exibir_imagens(it)
# Out:
# id: 0
# H:8.660602414580088
# area: 890
# bbox: (137, 313, 0, 200, 405, 1)
# bbox_area: 361500
# centroid: (168.0, 358.5, 0.0)
# equivalent_diameter: 11.934304873061132
# extent: 0.15355417529330573
#
# id: 1
# H:8.651306546587348
# area: 884
# bbox: (137, 82, 0, 200, 173, 1)
# bbox_area: 361500
# centroid: (168.0, 127.0, 0.0)
# equivalent_diameter: 11.907425717030108
# extent: 0.15419501133786848
#
# id: 2
# H:9.160393416074845
# area: 938
# bbox: (79, 21, 0, 115, 148, 1)
# bbox_area: 361500
# centroid: (96.5, 84.0, 0.0)
# equivalent_diameter: 12.145108678085549
# extent: 0.205161854768154
#
# id: 3
# H:8.933561272061443
# area: 692
# bbox: (52, 401, 0, 113, 462, 1)
# bbox_area: 361500
# centroid: (82.0, 431.0, 0.0)
# equivalent_diameter: 10.974106166962038
# extent: 0.18597151303413062
#
# id: 4
# H:9.16121274830945
# area: 938
# bbox: (47, 281, 0, 113, 378, 1)
# bbox_area: 361500
# centroid: (79.5, 329.0, 0.0)
# equivalent_diameter: 12.145108678085549
# extent: 0.1465167135270228
# ...
